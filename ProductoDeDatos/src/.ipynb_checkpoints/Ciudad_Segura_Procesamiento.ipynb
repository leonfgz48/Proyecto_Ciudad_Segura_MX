# %%
 #%pip install sagemaker  --upgrade --quiet

# %%
#%pip install cufflinks termcolor

# %%
""" Ciudad Segura MX ETL classifier and recognition

Notebook creado con la finalidad de procesar los datos de los delitos, 
hacer una clasificacion de delitos y hacer un match de los retratos para reconocimiento facial. 

Este Notebook se corre en Sagemaker, obtiene los datos crudos de S3, y exporta la data limpia a S3
    
"""
# Out:
# ' Ciudad Segura MX ETL classifier and recognition\n\nNotebook creado con la finalidad de procesar los datos de los delitos, \nhacer una clasificacion de delitos y hacer un match de los retratos para reconocimiento facial. \n\nEste Notebook se corre en Sagemaker, obtiene los datos crudos de S3, y exporta la data limpia a S3\n    \n'

# %% [markdown]
# ## LIBRERIAS

# %%
import pathlib
#bibliotecas
import sys
import pandas as pd
from IPython.core.display import display
pd.options.mode.chained_assignment = None
from scipy.stats import chisquare
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from statistics import mode
import numpy as np
import nltk
from sklearn.decomposition import PCA
import random
import re
import boto3
from scipy.sparse import hstack
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ### Importación de librería personal

# %%
#Importando módulo con funciones a utilizar
sys.path.append('../librerias')
#from funciones import *
from limpieza_datos import *

# %% [markdown]
# ## Lectura de dataset desde S3

# %%
s3 = boto3.resource('s3')

bucket_name = "itam-analytics-alberto"
bucket_prefix = "delitos/rawData/csv"
bucket = s3.Bucket(bucket_name)
prefix_objs = bucket.objects.filter(Prefix= bucket_prefix )

# Se toman del S3 todos los años(2019 -2023) y se van concatenando en un mismo dataframe 
df = pd.DataFrame()
for obj in prefix_objs:
    try:
        key = obj.key
        temp = pd.read_csv(obj.get()['Body'])     
        df =pd.concat([df, temp])
    except:
        continue
df.head()
# Out:
#    Unnamed: 0  idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0         1.0  8324429.0        2019      Enero  2019-01-04
# 1         2.0  8324430.0        2019      Enero  2019-01-04
# 2         3.0  8324431.0        2019      Enero  2019-01-04
# 3         4.0  8324435.0        2019      Enero  2019-01-04
# 4         5.0  8324438.0        2019      Enero  2019-01-04
#
#                                               Delito  \
# 0                                             FRAUDE
# 1  PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...
# 2  ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLE...
# 3  ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 4                  ROBO DE MOTOCICLETA SIN VIOLENCIA
#
#                                            Categoria       Sexo  Edad  \
# 0                             DELITO DE BAJO IMPACTO  Masculino  62.0
# 1                             DELITO DE BAJO IMPACTO   Femenino  38.0
# 2  ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...  Masculino  42.0
# 3               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino  35.0
# 4               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino   NaN
#
#   TipoPersona  ...  Mes_hecho  FechaHecho  HoraHecho HoraInicio  \
# 0      FISICA  ...     Agosto  2018-08-29   12:00:00   12:19:00
# 1      FISICA  ...  Diciembre  2018-12-15   15:00:00   12:20:00
# 2      FISICA  ...  Diciembre  2018-12-22   15:30:00   12:23:00
# 3      FISICA  ...      Enero  2019-01-04   06:00:00   12:27:00
# 4      FISICA  ...      Enero  2019-01-03   20:00:00   12:35:00
#
#   alcaldia_hechos municipio_hechos                colonia_datos  \
# 0  ALVARO OBREGON              NaN                GUADALUPE INN
# 1    AZCAPOTZALCO              NaN  VICTORIA DE LAS DEMOCRACIAS
# 2        COYOACAN              NaN              COPILCO EL BAJO
# 3       IZTACALCO              NaN                  PANTITLAN V
# 4      IZTAPALAPA              NaN         LAS AMERICAS (U HAB)
#
#           fgj_colonia_registro   latitud  longitud
# 0                GUADALUPE INN  19.36125 -99.18314
# 1  VICTORIA DE LAS DEMOCRACIAS  19.47181 -99.16458
# 2   COPILCO UNIVERSIDAD ISSSTE  19.33797 -99.18611
# 3           AGRÍCOLA PANTITLAN  19.40327 -99.05983
# 4                  PROGRESISTA  19.35480 -99.06324
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (1038430, 23)

# %% [markdown]
# # Limpieza de datos

# %%
# Ver el grado de valores faltantes para cada columna 
completitud(df)
# Out:
#                  columna    total  completitud
# 0       municipio_hechos  1028246     0.980711
# 1                   Edad   366188    64.736381
# 2                   Sexo   190025    81.700741
# 3          colonia_datos    73721    92.900725
# 4             Unnamed: 0    64344    93.803723
# 5              Categoria    64344    93.803723
# 6   fgj_colonia_registro    50410    95.145556
# 7               longitud    50204    95.165394
# 8                latitud    50202    95.165587
# 9            TipoPersona     6645    99.360092
# 10             Año_hecho      377    99.963695
# 11             Mes_hecho      377    99.963695
# 12            FechaHecho      377    99.963695
# 13             HoraHecho      368    99.964562
# 14       CalidadJuridica        1    99.999904
# 15            HoraInicio        1    99.999904
# 16           FechaInicio        0   100.000000
# 17       alcaldia_hechos        0   100.000000
# 18            Mes_inicio        0   100.000000
# 19            Año_inicio        0   100.000000
# 20             idCarpeta        0   100.000000
# 21                Delito        0   100.000000
# 22           competencia        0   100.000000

# %%
#ELiminamos columnas con missings mayor al 40%
df =  df.drop(columns=['municipio_hechos'])
df = df.drop('Unnamed: 0', axis=1)

# %%
#Imputamos por media y moda para edad, sexo y colonia
df['Edad'] = df['Edad'].fillna(np.nanmean(df['Edad']))
df['Sexo'] = df['Sexo'].fillna(mode(df['Sexo']))
df['colonia_datos'] = df['colonia_datos'].fillna(mode(df['colonia_datos']))

# %%
#Eliminamos registros con pocos nan
df = df.dropna(subset=['colonia_datos', 'fgj_colonia_registro', 'longitud','latitud','TipoPersona','FechaHecho','Mes_hecho','Año_hecho','HoraHecho','HoraInicio','CalidadJuridica'])

# %%
# Verificar el grado de valores faltantes para cada columna 
completitud(df)
# Out:
#                  columna  total  completitud
# 0              Categoria  60123    93.723621
# 1              idCarpeta      0   100.000000
# 2   fgj_colonia_registro      0   100.000000
# 3          colonia_datos      0   100.000000
# 4        alcaldia_hechos      0   100.000000
# 5             HoraInicio      0   100.000000
# 6              HoraHecho      0   100.000000
# 7             FechaHecho      0   100.000000
# 8              Mes_hecho      0   100.000000
# 9              Año_hecho      0   100.000000
# 10           competencia      0   100.000000
# 11       CalidadJuridica      0   100.000000
# 12           TipoPersona      0   100.000000
# 13                  Edad      0   100.000000
# 14                  Sexo      0   100.000000
# 15                Delito      0   100.000000
# 16           FechaInicio      0   100.000000
# 17            Mes_inicio      0   100.000000
# 18            Año_inicio      0   100.000000
# 19               latitud      0   100.000000
# 20              longitud      0   100.000000

# %%
df.shape
# Out:
# (957925, 21)

# %%
df.head()
# Out:
#    idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0  8324429.0        2019      Enero  2019-01-04
# 1  8324430.0        2019      Enero  2019-01-04
# 2  8324431.0        2019      Enero  2019-01-04
# 3  8324435.0        2019      Enero  2019-01-04
# 4  8324438.0        2019      Enero  2019-01-04
#
#                                               Delito  \
# 0                                             FRAUDE
# 1  PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...
# 2  ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLE...
# 3  ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 4                  ROBO DE MOTOCICLETA SIN VIOLENCIA
#
#                                            Categoria       Sexo       Edad  \
# 0                             DELITO DE BAJO IMPACTO  Masculino  62.000000
# 1                             DELITO DE BAJO IMPACTO   Femenino  38.000000
# 2  ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...  Masculino  42.000000
# 3               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino  35.000000
# 4               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino  38.822344
#
#   TipoPersona        CalidadJuridica  ... Año_hecho  Mes_hecho  FechaHecho  \
# 0      FISICA               OFENDIDO  ...    2018.0     Agosto  2018-08-29
# 1      FISICA  VICTIMA Y DENUNCIANTE  ...    2018.0  Diciembre  2018-12-15
# 2      FISICA  VICTIMA Y DENUNCIANTE  ...    2018.0  Diciembre  2018-12-22
# 3      FISICA  VICTIMA Y DENUNCIANTE  ...    2019.0      Enero  2019-01-04
# 4      FISICA                VICTIMA  ...    2019.0      Enero  2019-01-03
#
#   HoraHecho HoraInicio alcaldia_hechos                colonia_datos  \
# 0  12:00:00   12:19:00  ALVARO OBREGON                GUADALUPE INN
# 1  15:00:00   12:20:00    AZCAPOTZALCO  VICTORIA DE LAS DEMOCRACIAS
# 2  15:30:00   12:23:00        COYOACAN              COPILCO EL BAJO
# 3  06:00:00   12:27:00       IZTACALCO                  PANTITLAN V
# 4  20:00:00   12:35:00      IZTAPALAPA         LAS AMERICAS (U HAB)
#
#           fgj_colonia_registro   latitud  longitud
# 0                GUADALUPE INN  19.36125 -99.18314
# 1  VICTORIA DE LAS DEMOCRACIAS  19.47181 -99.16458
# 2   COPILCO UNIVERSIDAD ISSSTE  19.33797 -99.18611
# 3           AGRÍCOLA PANTITLAN  19.40327 -99.05983
# 4                  PROGRESISTA  19.35480 -99.06324
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Consistencia

# %%
# Ver que los tipos de las columnas sean las adecuadas 
df.dtypes
# Out:
# idCarpeta               float64
# Año_inicio                int64
# Mes_inicio               object
# FechaInicio              object
# Delito                   object
# Categoria                object
# Sexo                     object
# Edad                    float64
# TipoPersona              object
# CalidadJuridica          object
# competencia              object
# Año_hecho               float64
# Mes_hecho                object
# FechaHecho               object
# HoraHecho                object
# HoraInicio               object
# alcaldia_hechos          object
# colonia_datos            object
# fgj_colonia_registro     object
# latitud                 float64
# longitud                float64
# dtype: object

# %%
# Eliminar todas las filas con valores de fecha fuera de los límites válidos
df = df[pd.to_datetime(df['FechaHecho'], errors='coerce').notnull()]

# %%
df['idCarpeta']=df['idCarpeta'].astype('Int64')
df['FechaInicio']=pd.to_datetime(df['FechaInicio'])
df['Edad']=df['Edad'].astype('int')
df['Año_hecho']=df['Año_hecho'].astype('Int64')
df['FechaHecho']=pd.to_datetime(df['FechaHecho'])

# %%
df.dtypes
# Out:
# idCarpeta                        Int64
# Año_inicio                       int64
# Mes_inicio                      object
# FechaInicio             datetime64[ns]
# Delito                          object
# Categoria                       object
# Sexo                            object
# Edad                             int64
# TipoPersona                     object
# CalidadJuridica                 object
# competencia                     object
# Año_hecho                        Int64
# Mes_hecho                       object
# FechaHecho              datetime64[ns]
# HoraHecho                       object
# HoraInicio                      object
# alcaldia_hechos                 object
# colonia_datos                   object
# fgj_colonia_registro            object
# latitud                        float64
# longitud                       float64
# dtype: object

# %% [markdown]
# ## Ingeniería de variables

# %%
df['dia_inicio'] = df['FechaInicio'].dt.day
df['dia_hecho'] = df['FechaHecho'].dt.day

# %%
df[['horas_hecho', 'minutos_hecho', 'segundos_hecho']] = df['HoraHecho'].str.split(':', expand=True)
df[['horas_inicio', 'minutos_inicio', 'segundos_inicio']] = df['HoraInicio'].str.split(':', expand=True)
df['horas_hecho'] = df['horas_hecho'].astype('int')
df['minutos_hecho'] = df['minutos_hecho'].astype('int')
df['segundos_hecho'] = df['segundos_hecho'].astype('int')
df['horas_inicio'] = df['horas_inicio'].astype('int')
df['minutos_inicio'] = df['minutos_inicio'].astype('int')
df['segundos_inicio'] = df['segundos_inicio'].astype('int')

# %%
df.head()
# Out:
#    idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0    8324429        2019      Enero  2019-01-04
# 1    8324430        2019      Enero  2019-01-04
# 2    8324431        2019      Enero  2019-01-04
# 3    8324435        2019      Enero  2019-01-04
# 4    8324438        2019      Enero  2019-01-04
#
#                                               Delito  \
# 0                                             FRAUDE
# 1  PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...
# 2  ROBO A TRANSEUNTE SALIENDO DEL BANCO CON VIOLE...
# 3  ROBO DE VEHICULO DE SERVICIO PARTICULAR SIN VI...
# 4                  ROBO DE MOTOCICLETA SIN VIOLENCIA
#
#                                            Categoria       Sexo  Edad  \
# 0                             DELITO DE BAJO IMPACTO  Masculino    62
# 1                             DELITO DE BAJO IMPACTO   Femenino    38
# 2  ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...  Masculino    42
# 3               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino    35
# 4               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino    38
#
#   TipoPersona        CalidadJuridica  ...   latitud  longitud dia_inicio  \
# 0      FISICA               OFENDIDO  ...  19.36125 -99.18314          4
# 1      FISICA  VICTIMA Y DENUNCIANTE  ...  19.47181 -99.16458          4
# 2      FISICA  VICTIMA Y DENUNCIANTE  ...  19.33797 -99.18611          4
# 3      FISICA  VICTIMA Y DENUNCIANTE  ...  19.40327 -99.05983          4
# 4      FISICA                VICTIMA  ...  19.35480 -99.06324          4
#
#   dia_hecho horas_hecho minutos_hecho segundos_hecho horas_inicio  \
# 0        29          12             0              0           12
# 1        15          15             0              0           12
# 2        22          15            30              0           12
# 3         4           6             0              0           12
# 4         3          20             0              0           12
#
#   minutos_inicio  segundos_inicio
# 0             19                0
# 1             20                0
# 2             23                0
# 3             27                0
# 4             35                0
#
# [5 rows x 29 columns]

# %%
df['FechaHecho'] = pd.to_datetime(df['FechaHecho'],format='%Y-%m-%d')
df['FechaInicio'] = pd.to_datetime(df['FechaInicio'],format='%Y-%m-%d')
switcher ={
        0 : "Lunes",
        1 : "Martes",
        2 :"Miercoles",
        3 :"Jueves",
        4 :"Viernes",
        5 :"Sabado",
        6 :"Domingo"
    }
df['Dia_semana_inicio'] = list(map(lambda day_week : switcher.get(day_week.weekday(), "otro"),df.FechaInicio))
df['Dia_semana_hecho']  = list(map(lambda day_week : switcher.get(day_week.weekday(), "otro"),df.FechaHecho))

# %% [markdown]
# ## Stopwords

# %%
df['Delito'] = df['Delito'].str.replace(r'\(|\)', '', regex=True)

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('spanish'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Función para eliminar stop words
def remove_stopwords(text):
    words = text.split()
    clean_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(clean_words)

# %%
# Aplicar la función a la columna 'texto'
df['Delito'] = df['Delito'].apply(remove_stopwords)

# %%
df.head()
# Out:
#    idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0    8324429        2019      Enero  2019-01-04
# 1    8324430        2019      Enero  2019-01-04
# 2    8324431        2019      Enero  2019-01-04
# 3    8324435        2019      Enero  2019-01-04
# 4    8324438        2019      Enero  2019-01-04
#
#                                               Delito  \
# 0                                             FRAUDE
# 1  PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...
# 2           ROBO TRANSEUNTE SALIENDO BANCO VIOLENCIA
# 3        ROBO VEHICULO SERVICIO PARTICULAR VIOLENCIA
# 4                         ROBO MOTOCICLETA VIOLENCIA
#
#                                            Categoria       Sexo  Edad  \
# 0                             DELITO DE BAJO IMPACTO  Masculino    62
# 1                             DELITO DE BAJO IMPACTO   Femenino    38
# 2  ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...  Masculino    42
# 3               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino    35
# 4               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino    38
#
#   TipoPersona        CalidadJuridica  ... dia_inicio  dia_hecho horas_hecho  \
# 0      FISICA               OFENDIDO  ...          4         29          12
# 1      FISICA  VICTIMA Y DENUNCIANTE  ...          4         15          15
# 2      FISICA  VICTIMA Y DENUNCIANTE  ...          4         22          15
# 3      FISICA  VICTIMA Y DENUNCIANTE  ...          4          4           6
# 4      FISICA                VICTIMA  ...          4          3          20
#
#   minutos_hecho segundos_hecho horas_inicio minutos_inicio segundos_inicio  \
# 0             0              0           12             19               0
# 1             0              0           12             20               0
# 2            30              0           12             23               0
# 3             0              0           12             27               0
# 4             0              0           12             35               0
#
#   Dia_semana_inicio  Dia_semana_hecho
# 0           Viernes         Miercoles
# 1           Viernes            Sabado
# 2           Viernes            Sabado
# 3           Viernes           Viernes
# 4           Viernes            Jueves
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Particion por años

# %%
#Dividir el dataframe en 2 : (2019-2022) y (2023)
delitos = df[df["Año_inicio"]!=2023]
delitos_2023 = df[df["Año_inicio"]==2023]

# %%
delitos_2023.drop(['Categoria'], axis=1)
# Out:
#        idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0        9361878        2023      Enero  2023-01-01
# 1        9361879        2023      Enero  2023-01-01
# 2        9361880        2023      Enero  2023-01-01
# 3        9361881        2023      Enero  2023-01-01
# 5        9361883        2023      Enero  2023-01-01
# ...          ...         ...        ...         ...
# 64339    9429532        2023      Marzo  2023-03-31
# 64340    9429533        2023      Marzo  2023-03-31
# 64341    9429534        2023      Marzo  2023-03-31
# 64342    9429535        2023      Marzo  2023-03-31
# 64343    9429536        2023      Marzo  2023-03-31
#
#                                                   Delito       Sexo  Edad  \
# 0          LESIONES CULPOSAS TRANSITO VEHICULAR COLISION  Masculino    38
# 1                  ROBO TRANSEUNTE VIA PUBLICA VIOLENCIA  Masculino    50
# 2            ROBO VEHICULO SERVICIO PARTICULAR VIOLENCIA  Masculino    34
# 3          LESIONES CULPOSAS TRANSITO VEHICULAR COLISION  Masculino    38
# 5                                           ROBO OBJETOS  Masculino    38
# ...                                                  ...        ...   ...
# 64339  ROBO S/V DENTRO NEGOCIOS, AUTOSERVICIOS, CONVE...   Femenino    69
# 64340                                 VIOLENCIA FAMILIAR   Femenino    17
# 64341                     ROBO OBJETOS INTERIOR VEHICULO   Femenino    43
# 64342                                       ROBO OBJETOS   Femenino    39
# 64343                                 VIOLENCIA FAMILIAR   Femenino    41
#
#       TipoPersona        CalidadJuridica  competencia  ...  dia_inicio  \
# 0           MORAL               OFENDIDO  FUERO COMUN  ...           1
# 1          FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...           1
# 2          FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...           1
# 3          FISICA              LESIONADO  FUERO COMUN  ...           1
# 5          FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...           1
# ...           ...                    ...          ...  ...         ...
# 64339      FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...          31
# 64340      FISICA                VICTIMA  FUERO COMUN  ...          31
# 64341      FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...          31
# 64342      FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...          31
# 64343      FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...          31
#
#       dia_hecho horas_hecho minutos_hecho segundos_hecho horas_inicio  \
# 0            31          22             8              0            0
# 1            31          23            50              0            0
# 2            31          20            30              0            0
# 3            31          23            30              0            0
# 5            31          23            15              0            1
# ...         ...         ...           ...            ...          ...
# 64339        31           7            30              0           23
# 64340        30          22             0              0           23
# 64341        31           7             0              0           23
# 64342        31          10             1              0           23
# 64343        31          17            30              0           23
#
#       minutos_inicio segundos_inicio  Dia_semana_inicio  Dia_semana_hecho
# 0                  9               0            Domingo            Sabado
# 1                 41               0            Domingo            Sabado
# 2                 44               0            Domingo            Sabado
# 3                 47               0            Domingo            Sabado
# 5                  4               0            Domingo            Sabado
# ...              ...             ...                ...               ...
# 64339             48               0            Viernes           Viernes
# 64340             49               0            Viernes            Jueves
# 64341             51               0            Viernes           Viernes
# 64342             54               0            Viernes           Viernes
# 64343             55               0            Viernes           Viernes
#
# [60123 rows x 30 columns]

# %% [markdown]
# # Modelo

# %% [markdown]
# ## CountVectorizer

# %%
# Separar características de texto y numéricas
X_text = delitos['Delito']
X_2023 = delitos_2023['Delito']
y = delitos['Categoria']

# Crear matriz de frecuencia de términos
vectorizer = CountVectorizer(max_features=100)
X_text = vectorizer.fit_transform(X_text)
X_2023 = vectorizer.fit_transform(X_2023)

# %%
columns = vectorizer.get_feature_names()
X_text = pd.DataFrame(X_text.toarray(), columns=columns)

# %%
X = X_text

# %% [markdown]
# ## Train, Test, validation script

# %%
# Dividir conjunto de datos en entrenamiento y prueba
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Model training

# %%
# Entrenar modelo de clasificación
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# ## Model evaluation

# %%
# Evaluar modelo en conjunto de val
score = clf.score(X_val, y_val)
print('Accuracy:', score)
# Out:
# Accuracy: 0.9033420397525075

# %% [markdown]
# ## Model labeling

# %% [markdown]
# Juntarle al datafrane de 2023 la prediccion y_pred

# %%
y_pred = clf.predict(X_2023)

# %%
# Agregarle al 2023 la categoria que arrojó el modelo 
delitos_2023['Categoria'] = y_pred

# %%
# Unir datos  del (2019-2022) con los datos del 2023 
df =pd.concat([delitos, delitos_2023])
df
# Out:
#        idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0        8324429        2019      Enero  2019-01-04
# 1        8324430        2019      Enero  2019-01-04
# 2        8324431        2019      Enero  2019-01-04
# 3        8324435        2019      Enero  2019-01-04
# 4        8324438        2019      Enero  2019-01-04
# ...          ...         ...        ...         ...
# 64339    9429532        2023      Marzo  2023-03-31
# 64340    9429533        2023      Marzo  2023-03-31
# 64341    9429534        2023      Marzo  2023-03-31
# 64342    9429535        2023      Marzo  2023-03-31
# 64343    9429536        2023      Marzo  2023-03-31
#
#                                                   Delito  \
# 0                                                 FRAUDE
# 1      PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...
# 2               ROBO TRANSEUNTE SALIENDO BANCO VIOLENCIA
# 3            ROBO VEHICULO SERVICIO PARTICULAR VIOLENCIA
# 4                             ROBO MOTOCICLETA VIOLENCIA
# ...                                                  ...
# 64339  ROBO S/V DENTRO NEGOCIOS, AUTOSERVICIOS, CONVE...
# 64340                                 VIOLENCIA FAMILIAR
# 64341                     ROBO OBJETOS INTERIOR VEHICULO
# 64342                                       ROBO OBJETOS
# 64343                                 VIOLENCIA FAMILIAR
#
#                                                Categoria       Sexo  Edad  \
# 0                                 DELITO DE BAJO IMPACTO  Masculino    62
# 1                                 DELITO DE BAJO IMPACTO   Femenino    38
# 2      ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...  Masculino    42
# 3                   ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino    35
# 4                   ROBO DE VEHÍCULO CON Y SIN VIOLENCIA  Masculino    38
# ...                                                  ...        ...   ...
# 64339                             DELITO DE BAJO IMPACTO   Femenino    69
# 64340                             DELITO DE BAJO IMPACTO   Femenino    17
# 64341                                          SECUESTRO   Femenino    43
# 64342                                 HECHO NO DELICTIVO   Femenino    39
# 64343                             DELITO DE BAJO IMPACTO   Femenino    41
#
#       TipoPersona        CalidadJuridica  ... dia_inicio  dia_hecho  \
# 0          FISICA               OFENDIDO  ...          4         29
# 1          FISICA  VICTIMA Y DENUNCIANTE  ...          4         15
# 2          FISICA  VICTIMA Y DENUNCIANTE  ...          4         22
# 3          FISICA  VICTIMA Y DENUNCIANTE  ...          4          4
# 4          FISICA                VICTIMA  ...          4          3
# ...           ...                    ...  ...        ...        ...
# 64339      FISICA  VICTIMA Y DENUNCIANTE  ...         31         31
# 64340      FISICA                VICTIMA  ...         31         30
# 64341      FISICA  VICTIMA Y DENUNCIANTE  ...         31         31
# 64342      FISICA  VICTIMA Y DENUNCIANTE  ...         31         31
# 64343      FISICA  VICTIMA Y DENUNCIANTE  ...         31         31
#
#       horas_hecho minutos_hecho segundos_hecho horas_inicio minutos_inicio  \
# 0              12             0              0           12             19
# 1              15             0              0           12             20
# 2              15            30              0           12             23
# 3               6             0              0           12             27
# 4              20             0              0           12             35
# ...           ...           ...            ...          ...            ...
# 64339           7            30              0           23             48
# 64340          22             0              0           23             49
# 64341           7             0              0           23             51
# 64342          10             1              0           23             54
# 64343          17            30              0           23             55
#
#       segundos_inicio Dia_semana_inicio  Dia_semana_hecho
# 0                   0           Viernes         Miercoles
# 1                   0           Viernes            Sabado
# 2                   0           Viernes            Sabado
# 3                   0           Viernes           Viernes
# 4                   0           Viernes            Jueves
# ...               ...               ...               ...
# 64339               0           Viernes           Viernes
# 64340               0           Viernes            Jueves
# 64341               0           Viernes           Viernes
# 64342               0           Viernes           Viernes
# 64343               0           Viernes           Viernes
#
# [957924 rows x 31 columns]

# %%
# Se pasó la columna de categoría al final del dataframe 
column2 = df.pop('Categoria')
df['Categoria'] = column2

# %% [markdown]
# ### Agregar columnas de retrato para posteriormente usarlas con Rekognition

# %%
#Simulamos retrato hablado generando un random entre 1 a 13 (#de retratos con los que contamos)
random_numbers = [random.randint(1, 13) for _ in range(len(df))]
# Agregar la columna de números aleatorios al DataFrame
df['retrato'] = random_numbers

# %% [markdown]
# # Código para detectar sospechosos con el modelo de rekognition

# %% [markdown]
# ## Obtener las rutas para todas las imágenes del S3

# %%
s3 = boto3.resource('s3')
bucket_name = "itam-analytics-alberto"
bucket_prefix_ret = "delitos/img/retratos"
bucket_prefix_sos = "delitos/img/sospechosos"

my_bucket = s3.Bucket(bucket_name)

ret = []
sos =[]

# Retratos 
for my_bucket_object in my_bucket.objects.filter(Prefix=bucket_prefix_ret):
    # Obtener los nombres de las rutas para todos los retratos  
    ret.append(my_bucket_object.key)


ret.pop(0) 

# Sospechosos
for my_bucket_object in my_bucket.objects.filter(Prefix=bucket_prefix_sos):
   # Obtener los nombres de las rutas para todos los sospechosos
     sos.append(my_bucket_object.key)


sos.pop(0)
# Out:
# 'delitos/img/sospechosos/'

# %%
rekognition = boto3.client('rekognition',
                           aws_access_key_id='SECRET', 
                           aws_secret_access_key='SECRET', region_name='us-east-1')

# %%
# Crear un diccionario en el que la llave sean todos los retratos posibles 
all_retratos = df.retrato.unique()
ret_sos_relation = {key: None for key in all_retratos}
print(ret_sos_relation)
# Out:
# {11: None, 9: None, 6: None, 8: None, 5: None, 7: None, 2: None, 13: None, 4: None, 1: None, 10: None, 12: None, 3: None}

# %%
for i in range(0,len(ret),1):
    best_similarity= 0
    for j in range(0,len(sos),1):
        # Carga las imágenes a comparar
        response = rekognition.compare_faces(
            SourceImage={
                 'S3Object': {
                     'Bucket': 'itam-analytics-alberto',
                     'Name':   ret[i]
                             }},
            TargetImage={
                'S3Object': {
                     'Bucket': 'itam-analytics-alberto',
                     'Name':   sos[j]
                            }},
            SimilarityThreshold=0  # Puedes ajustar este valor según tu caso
        )

        # Obtiene la puntuación de similitud
        similarity = response['FaceMatches'][0]['Similarity']
        if similarity >= best_similarity:
            best_similarity = similarity
            # LLenar el diccionario de retratos con los sospechosos asignados y el nivel de similitud 
            key = int(re.findall("\d+", ret[i])[0]) 
            bestImgSimil = int(re.findall("\d+", sos[j])[0]) 
            ret_sos_relation[key] = [ bestImgSimil,similarity]

# %%
# Ver el diccionario lleno con retratos, sospechosos y porcentaje de similitud 
print(ret_sos_relation)
# Out:
# {11: [11, 99.96415710449219], 9: [9, 2.584242820739746], 6: [10, 3.0010321140289307], 8: [8, 1.1975784301757812], 5: [5, 14.961284637451172], 7: [7, 15.112532615661621], 2: [2, 70.27783203125], 13: [13, 94.7482681274414], 4: [4, 79.49003601074219], 1: [1, 85.18539428710938], 10: [10, 6.86883020401001], 12: [12, 99.66559600830078], 3: [7, 2.0562756061553955]}

# %%
# Crear las columnas de sospechosos y porcentaje de similitud 
df['sospechoso'] = np.nan
df['porcentaje_similitud'] = np.nan

# %%
df['sospechoso'] =df['retrato'].apply(lambda x: ret_sos_relation[x][0])
df['porcentaje_similitud'] = df['retrato'].apply(lambda x: ret_sos_relation[x][1])

# %% [markdown]
# # Send clean data to S3

# %%
cols = ['idCarpeta', 'Año_inicio', 'Mes_inicio', 'FechaInicio', 'Delito',
       'Sexo', 'Edad', 'TipoPersona', 'CalidadJuridica', 'competencia',
       'Año_hecho', 'Mes_hecho', 'FechaHecho', 'HoraHecho', 'HoraInicio',
       'alcaldia_hechos', 'colonia_datos', 'fgj_colonia_registro', 'latitud',
       'longitud', 'dia_inicio', 'dia_hecho', 'horas_hecho', 'minutos_hecho',
       'segundos_hecho', 'horas_inicio', 'minutos_inicio', 'segundos_inicio',
       'Dia_semana_inicio', 'Dia_semana_hecho', 'Categoria', 'retrato',
       'sospechoso', 'porcentaje_similitud']
df = df[cols]

# %%
s3 = boto3.resource('s3')
bucket_name = "itam-analytics-alberto"
my_bucket = s3.Bucket(bucket_name)

df.to_csv('s3://itam-analytics-alberto/delitos/cleanData/delitos.csv', index=False)

# %%
df.head()
# Out:
#    idCarpeta  Año_inicio Mes_inicio FechaInicio  \
# 0    8324429        2019      Enero  2019-01-04
# 1    8324430        2019      Enero  2019-01-04
# 2    8324431        2019      Enero  2019-01-04
# 3    8324435        2019      Enero  2019-01-04
# 4    8324438        2019      Enero  2019-01-04
#
#                                               Delito       Sexo  Edad  \
# 0                                             FRAUDE  Masculino    62
# 1  PRODUCCIÓN, IMPRESIÓN, ENAJENACIÓN, DISTRIBUCI...   Femenino    38
# 2           ROBO TRANSEUNTE SALIENDO BANCO VIOLENCIA  Masculino    42
# 3        ROBO VEHICULO SERVICIO PARTICULAR VIOLENCIA  Masculino    35
# 4                         ROBO MOTOCICLETA VIOLENCIA  Masculino    38
#
#   TipoPersona        CalidadJuridica  competencia  ...  segundos_hecho  \
# 0      FISICA               OFENDIDO  FUERO COMUN  ...               0
# 1      FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...               0
# 2      FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...               0
# 3      FISICA  VICTIMA Y DENUNCIANTE  FUERO COMUN  ...               0
# 4      FISICA                VICTIMA  FUERO COMUN  ...               0
#
#   horas_inicio minutos_inicio segundos_inicio Dia_semana_inicio  \
# 0           12             19               0           Viernes
# 1           12             20               0           Viernes
# 2           12             23               0           Viernes
# 3           12             27               0           Viernes
# 4           12             35               0           Viernes
#
#   Dia_semana_hecho                                          Categoria retrato  \
# 0        Miercoles                             DELITO DE BAJO IMPACTO      11
# 1           Sabado                             DELITO DE BAJO IMPACTO       9
# 2           Sabado  ROBO A CUENTAHABIENTE SALIENDO DEL CAJERO CON ...       6
# 3          Viernes               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA       8
# 4           Jueves               ROBO DE VEHÍCULO CON Y SIN VIOLENCIA       6
#
#    sospechoso  porcentaje_similitud
# 0          11             99.964157
# 1           9              2.584243
# 2          10              3.001032
# 3           8              1.197578
# 4          10              3.001032
#
# [5 rows x 34 columns]
